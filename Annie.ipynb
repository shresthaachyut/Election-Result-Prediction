# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

#Cleaning data
df = pd.read_csv('./Resources/CandidateSummaryAction.csv')
df['tot_dis'] = df['net_ope_exp'].str.replace("$","").str.replace(",","").str.replace("(","-").str.replace(")","")
df['net_ope_exp'] = df['net_ope_exp'].str.replace("$","").str.replace(",","").str.replace("(","-").str.replace(")","")
df['net_con'] = df['net_con'].str.replace("$","").str.replace(",","").str.replace("(","-").str.replace(")","")
df['cas_on_han_beg_of_per']= df['cas_on_han_beg_of_per'].str.replace("$","").str.replace(",","").str.replace("(","-").str.replace(")","")
df['cas_on_han_clo_of_per']= df['cas_on_han_clo_of_per'].str.replace("$","").str.replace(",","").str.replace("(","-").str.replace(")","")
df['tot_loa']= df['tot_loa'].str.replace("$","").str.replace(",","").str.replace("(","-").str.replace(")","")
df['can_loa'] = df['can_loa'].str.replace("$","").str.replace(",","").str.replace("(","-").str.replace(")","")
df['ind_ite_con']=df['ind_ite_con'].str.replace("$","").str.replace(",","").str.replace("(","-").str.replace(")","")
df['ind_uni_con']=df['ind_uni_con'].str.replace("$","").str.replace(",","").str.replace("(","-").str.replace(")","")
df['ind_con']=df['ind_con'].str.replace("$","").str.replace(",","").str.replace("(","-").str.replace(")","")
df['deb_owe_to_com'] = df ['deb_owe_to_com'].str.replace("$","").str.replace(",","")

df
# Out:
#          can_id                       can_nam can_off can_off_sta  \
# 0     H2GA12121              ALLEN, RICHARD W       H          GA
# 1     H6PA02171                 EVANS, DWIGHT       H          PA
# 2     H6FL04105              RUTHERFORD, JOHN       H          FL
# 3     H4MT01041                 ZINKE, RYAN K       H          MT
# 4     H8CA09060                  LEE, BARBARA       H          CA
# 5     H6NC04037               PRICE, DAVID E.       H          NC
# 6     H2WI02124                   POCAN, MARK       H          WI
# 7     H2MA09072                LYNCH, STEPHEN       H          MA
# 8     H6OR02116         WALDEN, GREGORY P MR.       H          OR
# 9     H2MA04073         KENNEDY, JOSEPH P III       H          MA
# 10    H8WI09050   SENSENBRENNER, F. JAMES JR.       H          WI
# 11    H0FL08208               WEBSTER, DANIEL       H          FL
# 12    H8ME01120            PINGREE, CHELLIE M       H          ME
# 13    H6FL01119                   GAETZ, MATT       H          FL
# 14    H6FL09070              BILIRAKIS, GUS M       H          FL
# 15    H4PA18131                   DOYLE, MIKE       H          PA
# 16    H8CO02137                  POLIS, JARED       H          CO
# 17    H6MN05183        ELLISON, KEITH MAURICE       H          MN
# 18    H8MO09153         LUETKEMEYER, W BLAINE       H          MO
# 19    H6IL18088           LAHOOD, DARIN MCKAY       H          IL
# 20    H8FL15107                   POSEY, BILL       H          FL
# 21    H4VA08224    BEYER, DONALD STERNOFF JR.       H          VA
# 22    H2MI14111      LAWRENCE, BRENDA LULENAR       H          MI
# 23    H0OH12062            TIBERI, PATRICK J.       H          OH
# 24    H0LA01087            SCALISE, STEVE MR.       H          LA
# 25    H6GA05217                LEWIS, JOHN R.       H          GA
# 26    H4CO04090               BUCK, KENNETH R       H          CO
# 27    H4AL06098                  PALMER, GARY       H          AL
# 28    H8OH05036       LATTA, ROBERT EDWARD MR       H          OH
# 29    H6FL19087               ROONEY, FRANCIS       H          FL
# ...         ...                           ...     ...         ...
# 1784  H6MS01180          MILLS, MICHAEL P. JR       H          MS
# 1785  H6MS01172            PIRKLE, GREGORY D.       H          MS
# 1786  H6CA46124            SANCHEZ, HEBERTO M       H          CA
# 1787  P60013968                     STEF, MEL       P          US
# 1788  P60007143        ZUTLER, DANIEL PAUL MR       P          US
# 1789  P60002458           JEWELL, ROGER HENRY       P          US
# 1790  P60006731        MILLER, RAYMOND MELVIN       P          US
# 1791  P60008364          VEGA, ISAAC ADAM MR.       P          US
# 1792  P00004275               BROWN, HARLEY D       P          US
# 1793  H6NY11182                   LANE, JAMES       H          NY
# 1794  H6MS01164                COLLINS, NANCY       H          MS
# 1795  S6CA00618            ALBERTSON, STEWART       S          CA
# 1796  P60008125           CORNELL, PHILIP MR.       P          US
# 1797  P60007903      CULLISON, BROOKS ANDREWS       P          US
# 1798  P20002838           HILL, CHRISTOPHER V       P          US
# 1799  P60004900                JEROBOAN, KINS       P          US
# 1800  H6MS01198      JONES, ROGER STARNER DR.       H          MS
# 1801  P60005808             KAHN, LYNN SANDRA       P          US
# 1802  P60005733                 SHO, MUHAMMAD       P          US
# 1803  P20003158            STAINFIELD, TAMI L       P          US
# 1804  P60006814               LYNCH, DENNIS M       P          US
# 1805  P60006954         LYNCH, DENNIS MICHAEL       P          US
# 1806  P20003141          FERGUSON, JOHN GREEN       P          US
# 1807  P60005907      FLEMING-HODGE, LORI LYNN       P          US
# 1808  P60005535          EMRIT, RONALD SATISH       P          US
# 1809  P60005931   BUTTOCKS, SYDNEYS VOLUPTOUS       P          US
# 1810  S6CA00568                MOLNAR, ROBERT       S          CA
# 1811  S6MD03524               HOLMES, GREGORY       S          MD
# 1812  H6AS00031  HUNKIN-FINAU, VAITINASA SALU       H          AS
# 1813  H6AK00235               LINDBECK, STEVE       H          AK
#
#       can_off_dis can_par_aff can_inc_cha_ope_sea  \
# 0            12.0         REP           INCUMBENT
# 1             2.0         DEM          CHALLENGER
# 2             4.0         REP                OPEN
# 3             0.0         REP           INCUMBENT
# 4            13.0         DEM           INCUMBENT
# 5             4.0         DEM           INCUMBENT
# 6             2.0         DEM           INCUMBENT
# 7             8.0         DEM           INCUMBENT
# 8             2.0         REP           INCUMBENT
# 9             4.0         DEM           INCUMBENT
# 10            5.0         REP           INCUMBENT
# 11           11.0         REP           INCUMBENT
# 12            1.0         DEM           INCUMBENT
# 13            1.0         REP                OPEN
# 14           12.0         REP           INCUMBENT
# 15           14.0         DEM           INCUMBENT
# 16            2.0         DEM           INCUMBENT
# 17            5.0         DEM           INCUMBENT
# 18            3.0         REP           INCUMBENT
# 19           18.0         REP           INCUMBENT
# 20            8.0         REP           INCUMBENT
# 21            8.0         DEM           INCUMBENT
# 22           14.0         DEM           INCUMBENT
# 23           12.0         REP           INCUMBENT
# 24            1.0         REP           INCUMBENT
# 25            5.0         DEM           INCUMBENT
# 26            4.0         REP           INCUMBENT
# 27            6.0         REP           INCUMBENT
# 28            5.0         REP           INCUMBENT
# 29           19.0         REP                OPEN
# ...           ...         ...                 ...
# 1784          1.0         REP                OPEN
# 1785          1.0         REP                OPEN
# 1786         46.0         DEM                OPEN
# 1787          0.0         IND                OPEN
# 1788          0.0         IND                OPEN
# 1789          0.0         NNE                OPEN
# 1790          0.0         REP                OPEN
# 1791          0.0           W                OPEN
# 1792          0.0         NNE                OPEN
# 1793         11.0         GRE                OPEN
# 1794          1.0         REP                OPEN
# 1795          0.0         DEM                OPEN
# 1796          0.0         IND                OPEN
# 1797          0.0         REP                OPEN
# 1798          0.0         REP                OPEN
# 1799          0.0         REP                OPEN
# 1800          1.0         REP                OPEN
# 1801          0.0         IND                OPEN
# 1802          0.0         UNK                OPEN
# 1803          0.0         NNE                OPEN
# 1804          0.0         REP                OPEN
# 1805          0.0         REP                OPEN
# 1806          0.0         OTH                OPEN
# 1807          0.0         IND                OPEN
# 1808          0.0         DEM                OPEN
# 1809          0.0         IND                OPEN
# 1810          0.0         REP                OPEN
# 1811          0.0         REP                OPEN
# 1812          NaN         DEM                 NaN
# 1813          NaN         DEM                 NaN
#
#                                can_str1 can_str2            can_cit  ...  \
# 0                       2237 PICKENS RD      NaN            AUGUSTA  ...
# 1                           PO BOX 6578      NaN       PHILADELPHIA  ...
# 2               3817 VICKERS LAKE DRIVE      NaN       JACKSONVILLE  ...
# 3                          409 2ND ST W      NaN          WHITEFISH  ...
# 4                  409 13TH ST, 17TH FL      NaN            OAKLAND  ...
# 5                        P. O. BOX 1986      NaN            RALEIGH  ...
# 6                            PO BOX 327      NaN            MADISON  ...
# 7                       105 FARRAGUT RD      NaN       SOUTH BOSTON  ...
# 8                   1504 SHERMAN AVENUE      NaN         HOOD RIVER  ...
# 9                         PO BOX 590464      NaN             NEWTON  ...
# 10           N76 W14726 NORTH POINT DR.      NaN    MENOMONEE FALLS  ...
# 11                       P. O. BOX 1007      NaN            WEBSTER  ...
# 12                   138 TURNER FARM RD      NaN        NORTH HAVEN  ...
# 13                301 BROOKS STREET, SE      NaN  FORT WALTON BEACH  ...
# 14                           PO BOX 606      NaN     TARPON SPRINGS  ...
# 15                     205 HAWTHORNE CT      NaN         PITTSBURGH  ...
# 16                        P.O. BOX 4572      NaN            BOULDER  ...
# 17                          PO BOX 6072      NaN        MINNEAPOLIS  ...
# 18                      215 MAIN STREET      NaN       ST ELIZABETH  ...
# 19                 11607 N GLENSHIRE DR      NaN             DUNLAP  ...
# 20                     P. O. BOX 411486      NaN          MELBOURNE  ...
# 21            1751 POTOMAC GREENS DRIVE      NaN         ALEXANDRIA  ...
# 22                     20580 WAYLAND ST      NaN         SOUTHFIELD  ...
# 23                  6830 MAHOGANY DRIVE      NaN             GALENA  ...
# 24            234 JEFFERSON HEIGHTS AVE      NaN          JEFFERSON  ...
# 25                     2015 WALLACE RD.      NaN            ATLANTA  ...
# 26                        PO BOX 338018      NaN            GREELEY  ...
# 27                  1919 OXMOOR RD #235      NaN         BIRMINGHAM  ...
# 28                 1528 MUIRFIELD DRIVE      NaN      BOWLING GREEN  ...
# 29                     610 S. BOULEVARD      NaN              TAMPA  ...
# ...                                 ...      ...                ...  ...
# 1784             100 A WEST MAIN STREET      NaN             FULTON  ...
# 1785                      P.O. BOX 7154      NaN             TUPELO  ...
# 1786                   81 RAINBOW RIDGE      NaN             POMONA  ...
# 1787                  1119 WHITE STREET      NaN           KEY WEST  ...
# 1788                 7300 SEA GRAPE AVE      NaN        PORT RICHEY  ...
# 1789                 316 N AVENUE A #82      NaN        CASA GRANDE  ...
# 1790                   325 S BLUE HERON      NaN              NAMPA  ...
# 1791                      18116 9TH ST.      NaN        BLOOMINGTON  ...
# 1792                    6086 HAPPY LANE      NaN              NAMPA  ...
# 1793                    269 12TH STREET      NaN           BROOKLYN  ...
# 1794                1604 BRIAR RIDGE RD      NaN             TUPELO  ...
# 1795   555 TWIN DOLPHIN DRIVE SUITE 130      NaN       REDWOOD CITY  ...
# 1796                   1502 15TH AVE SW      NaN            OLYMPIA  ...
# 1797                     235 W CHESTNUT      NaN              OLNEY  ...
# 1798  9900 CORPORATE CAMPUS DR STE 3000      NaN         LOUISVILLE  ...
# 1799         163-49 130TH AVENUE APT GA      NaN            JAMAICA  ...
# 1800            136 NORTH BROOKS STREET      NaN           PONTOTOC  ...
# 1801                         PO BOX 497      NaN         KENSINGTON  ...
# 1802                       PO BOX 38272      NaN            HOUSTON  ...
# 1803                         PO BOX 842      NaN         CHARLESTON  ...
# 1804                                NaN      NaN           AVENTURA  ...
# 1805                         PO BOX 704      NaN         AMAGANSETT  ...
# 1806                           PMB 1704      NaN               AZLE  ...
# 1807                     228 HICKS LANE      NaN        VIOLET HILL  ...
# 1808               4529 TOWNWALL STREET      NaN          LAS VEGAS  ...
# 1809                143 HIGHLAND AVENUE      NaN            BUFFALO  ...
# 1810                      PO BOX 321231      NaN          LOS GATOS  ...
# 1811                 13601 MACDERNUT CT      NaN     UPPER MARLBORO  ...
# 1812               PO BOX 252 VAILOAUTA      NaN          PAGO PAGO  ...
# 1813                       PO BOX 90025      NaN          ANCHORAGE  ...
#
#      cas_on_han_beg_of_per  cas_on_han_clo_of_per     net_con net_ope_exp  \
# 0                 60109.57              175613.35  1074949.50   907156.21
# 1                      NaN              105687.23  1406719.06  1298831.83
# 2                      NaN               35645.09   650855.38   656210.29
# 3                 83815.78              399122.61  4938943.74  5055942.15
# 4                 83690.60              181338.23  1197676.61   949488.98
# 5                216409.21              274287.84   725854.52   430826.04
# 6                187549.87              412220.80   970385.04   445438.15
# 7                406586.74             1010654.62  1092218.56   459790.68
# 8                997259.73             1264468.82  3004650.64  1911215.54
# 9               1400008.58             2858165.71  2784362.26  1537844.39
# 10               393925.71              489657.75   365203.15   265824.16
# 11               162472.14               76985.57   830657.86   785298.58
# 12               215458.53              546889.99   571307.98   238294.57
# 13                     NaN               45404.66   951163.89   993759.23
# 14               429105.83              306900.57  1306012.36  1260554.41
# 15               210531.58              291751.36   777713.70   454476.55
# 16                10603.18               91824.88  1281823.94  1102838.77
# 17               162747.78              365620.60  2294848.39  1622329.10
# 18               965976.43             1941810.36  1795890.99   550469.87
# 19                     NaN              460882.83  2424378.83  1941921.99
# 20               342230.68              588576.15   837793.04   516550.17
# 21                86253.61              814750.02  1982462.14   742454.92
# 22                89131.21              228308.15   766433.08   498853.15
# 23              2501982.76             5201935.66  4258847.29  1318584.81
# 24               482793.91              455004.90   863953.07  2449513.59
# 25               184419.65              236216.43   980363.33   655566.55
# 26               140466.09              401585.47   808161.67   550056.91
# 27               189712.50              781799.96  1175074.52   451946.24
# 28               492878.98              879548.37   998358.48   384494.66
# 29                     NaN              281520.97  4550062.50  4718541.53
# ...                    ...                    ...         ...         ...
# 1784                   NaN                    NaN   101100.00   178100.00
# 1785                   NaN                    NaN   212756.00   459834.76
# 1786                   NaN                    NaN     3111.94     3111.94
# 1787                   NaN                    NaN         NaN         NaN
# 1788                   NaN                 950.00     4000.00     2200.00
# 1789                 11.00                   1.00         NaN         NaN
# 1790                   NaN                    NaN         NaN         NaN
# 1791                   NaN                    NaN         NaN         NaN
# 1792                754.92                1918.42    10487.10     9655.02
# 1793                   NaN                 257.89    14241.00    13356.89
# 1794                   NaN                    NaN   102538.35   247121.35
# 1795                   NaN                    NaN    15250.00    15221.00
# 1796                 50.00                  50.00         NaN         NaN
# 1797                   NaN                    NaN         NaN         NaN
# 1798                705.00                    NaN         NaN         NaN
# 1799                   NaN                    NaN         NaN         NaN
# 1800                   NaN                    NaN   140858.00   528638.39
# 1801                   NaN                 619.00         NaN         NaN
# 1802                   NaN                    NaN         NaN         NaN
# 1803               4413.35                2977.33    25025.00    22065.98
# 1804                   NaN                    NaN         NaN         NaN
# 1805                   NaN                    NaN         NaN         NaN
# 1806                   NaN                    NaN         NaN         NaN
# 1807               1000.00                 125.00         NaN         NaN
# 1808                   NaN                    NaN         NaN         NaN
# 1809               5000.00                5000.00         NaN         NaN
# 1810               1000.00                    NaN     1000.00     1000.00
# 1811                   NaN                    NaN         NaN         NaN
# 1812               1058.44                4561.00    41670.00    38167.44
# 1813                   NaN               64115.92   876316.81   792150.89
#
#      deb_owe_by_com deb_owe_to_com cov_sta_dat cov_end_dat winner     votes
# 0     $1,125,000.00            NaN    1/1/2015  10/19/2016      Y  158708.0
# 1               NaN            NaN   11/2/2015  10/19/2016      Y  310770.0
# 2        $60,000.00            NaN    4/1/2016  10/19/2016      Y  286018.0
# 3               NaN            NaN    1/1/2015  10/19/2016      Y  280476.0
# 4         $4,401.75            NaN    1/1/2015  10/19/2016      Y  277390.0
# 5               NaN            NaN    1/1/2015  10/19/2016      Y  275501.0
# 6               NaN            NaN    1/1/2015  10/19/2016      Y  273520.0
# 7               NaN        1750.00    1/1/2015  10/19/2016      Y  267944.0
# 8               NaN            NaN    1/1/2015  10/19/2016      Y  267179.0
# 9               NaN            NaN    1/1/2015  10/19/2016      Y  261356.0
# 10              NaN            NaN    1/1/2015  10/19/2016      Y  260705.0
# 11              NaN            NaN    1/1/2015  10/19/2016      Y  257881.0
# 12       $20,000.00            NaN    1/1/2015  10/19/2016      Y  255428.0
# 13      $120,000.00            NaN    1/1/2016  10/19/2016      Y  254280.0
# 14              NaN            NaN    1/1/2015  10/19/2016      Y  253347.0
# 15              NaN            NaN    1/1/2015  10/19/2016      Y  252709.0
# 16              NaN            NaN    1/1/2015  10/19/2016      Y  251988.0
# 17              NaN            NaN    1/1/2015  10/19/2016      Y  249957.0
# 18    $1,050,000.00            NaN    1/1/2015  10/19/2016      Y  248880.0
# 19              NaN            NaN    1/1/2015  10/19/2016      Y  248701.0
# 20              NaN            NaN    1/1/2015  10/19/2016      Y  246257.0
# 21              NaN            NaN    1/1/2015  10/19/2016      Y  245775.0
# 22              NaN            NaN    1/1/2015  10/19/2016      Y  244220.0
# 23              NaN            NaN    1/1/2015  10/19/2016      Y  243970.0
# 24              NaN            NaN    1/1/2015  10/19/2016      Y  243575.0
# 25              NaN            NaN    1/1/2015  10/19/2016      Y  241773.0
# 26              NaN            NaN    1/1/2015  10/19/2016      Y  241424.0
# 27              NaN            NaN    1/1/2015  10/19/2016      Y  240897.0
# 28              NaN            NaN    1/1/2015  10/19/2016      Y  240036.0
# 29      $450,000.00            NaN    4/1/2016  10/19/2016      Y  238975.0
# ...             ...            ...         ...         ...    ...       ...
# 1784            NaN            NaN    1/1/2015   9/30/2015    NaN       NaN
# 1785            NaN            NaN    1/1/2015   9/30/2015    NaN       NaN
# 1786            NaN            NaN   6/10/2015   9/30/2015    NaN       NaN
# 1787            NaN            NaN    7/1/2015   9/30/2015    NaN       NaN
# 1788            NaN            NaN   4/28/2015   9/30/2015    NaN       NaN
# 1789      $4,325.00            NaN    1/1/2015   8/30/2015    NaN       NaN
# 1790            NaN            NaN    4/8/2015   7/15/2015    NaN       NaN
# 1791            NaN            NaN   6/25/2015   7/15/2015    NaN       NaN
# 1792            NaN            NaN    1/1/2015    7/8/2015    NaN       NaN
# 1793            NaN            NaN    1/1/2015    7/7/2015    NaN       NaN
# 1794            NaN            NaN    1/1/2015    7/1/2015    NaN       NaN
# 1795      $1,098.00            NaN    1/1/2015   6/30/2015    NaN       NaN
# 1796            NaN            NaN    4/1/2015   6/30/2015    NaN       NaN
# 1797            NaN            NaN    6/9/2015   6/30/2015    NaN       NaN
# 1798            NaN            NaN    1/1/2015   6/30/2015    NaN       NaN
# 1799            NaN            NaN    1/1/2015   6/30/2015    NaN       NaN
# 1800            NaN            NaN    1/1/2015   6/30/2015    NaN       NaN
# 1801            NaN            NaN    4/1/2015   6/30/2015    NaN       NaN
# 1802          $1.00            NaN    1/1/2015   6/30/2015    NaN       NaN
# 1803            NaN            NaN    1/1/2015   6/30/2015    NaN       NaN
# 1804            NaN            NaN    5/1/2015   6/15/2015    NaN       NaN
# 1805            NaN            NaN    5/1/2015   6/15/2015    NaN       NaN
# 1806            NaN            NaN    7/1/2012   5/31/2015    NaN       NaN
# 1807            NaN            NaN    3/1/2015   4/30/2015    NaN       NaN
# 1808            NaN            NaN    1/1/2015    4/4/2015    NaN       NaN
# 1809            NaN            NaN    3/3/2015   3/31/2015    NaN       NaN
# 1810            NaN            NaN    1/1/2015   3/31/2015    NaN       NaN
# 1811            NaN            NaN   8/29/2017    2/1/2015    NaN       NaN
# 1812            NaN            NaN    7/1/2016  10/19/2016    NaN       NaN
# 1813     $13,979.83            NaN    4/1/2016  10/19/2016    NaN       NaN
#
# [1814 rows x 51 columns]

# %%
df.to_csv('./Resources/001_CleanData_CandidateSummaryAction.csv')
df
# Out:
#          can_id                       can_nam can_off can_off_sta  \
# 0     H2GA12121              ALLEN, RICHARD W       H          GA
# 1     H6PA02171                 EVANS, DWIGHT       H          PA
# 2     H6FL04105              RUTHERFORD, JOHN       H          FL
# 3     H4MT01041                 ZINKE, RYAN K       H          MT
# 4     H8CA09060                  LEE, BARBARA       H          CA
# 5     H6NC04037               PRICE, DAVID E.       H          NC
# 6     H2WI02124                   POCAN, MARK       H          WI
# 7     H2MA09072                LYNCH, STEPHEN       H          MA
# 8     H6OR02116         WALDEN, GREGORY P MR.       H          OR
# 9     H2MA04073         KENNEDY, JOSEPH P III       H          MA
# 10    H8WI09050   SENSENBRENNER, F. JAMES JR.       H          WI
# 11    H0FL08208               WEBSTER, DANIEL       H          FL
# 12    H8ME01120            PINGREE, CHELLIE M       H          ME
# 13    H6FL01119                   GAETZ, MATT       H          FL
# 14    H6FL09070              BILIRAKIS, GUS M       H          FL
# 15    H4PA18131                   DOYLE, MIKE       H          PA
# 16    H8CO02137                  POLIS, JARED       H          CO
# 17    H6MN05183        ELLISON, KEITH MAURICE       H          MN
# 18    H8MO09153         LUETKEMEYER, W BLAINE       H          MO
# 19    H6IL18088           LAHOOD, DARIN MCKAY       H          IL
# 20    H8FL15107                   POSEY, BILL       H          FL
# 21    H4VA08224    BEYER, DONALD STERNOFF JR.       H          VA
# 22    H2MI14111      LAWRENCE, BRENDA LULENAR       H          MI
# 23    H0OH12062            TIBERI, PATRICK J.       H          OH
# 24    H0LA01087            SCALISE, STEVE MR.       H          LA
# 25    H6GA05217                LEWIS, JOHN R.       H          GA
# 26    H4CO04090               BUCK, KENNETH R       H          CO
# 27    H4AL06098                  PALMER, GARY       H          AL
# 28    H8OH05036       LATTA, ROBERT EDWARD MR       H          OH
# 29    H6FL19087               ROONEY, FRANCIS       H          FL
# ...         ...                           ...     ...         ...
# 1784  H6MS01180          MILLS, MICHAEL P. JR       H          MS
# 1785  H6MS01172            PIRKLE, GREGORY D.       H          MS
# 1786  H6CA46124            SANCHEZ, HEBERTO M       H          CA
# 1787  P60013968                     STEF, MEL       P          US
# 1788  P60007143        ZUTLER, DANIEL PAUL MR       P          US
# 1789  P60002458           JEWELL, ROGER HENRY       P          US
# 1790  P60006731        MILLER, RAYMOND MELVIN       P          US
# 1791  P60008364          VEGA, ISAAC ADAM MR.       P          US
# 1792  P00004275               BROWN, HARLEY D       P          US
# 1793  H6NY11182                   LANE, JAMES       H          NY
# 1794  H6MS01164                COLLINS, NANCY       H          MS
# 1795  S6CA00618            ALBERTSON, STEWART       S          CA
# 1796  P60008125           CORNELL, PHILIP MR.       P          US
# 1797  P60007903      CULLISON, BROOKS ANDREWS       P          US
# 1798  P20002838           HILL, CHRISTOPHER V       P          US
# 1799  P60004900                JEROBOAN, KINS       P          US
# 1800  H6MS01198      JONES, ROGER STARNER DR.       H          MS
# 1801  P60005808             KAHN, LYNN SANDRA       P          US
# 1802  P60005733                 SHO, MUHAMMAD       P          US
# 1803  P20003158            STAINFIELD, TAMI L       P          US
# 1804  P60006814               LYNCH, DENNIS M       P          US
# 1805  P60006954         LYNCH, DENNIS MICHAEL       P          US
# 1806  P20003141          FERGUSON, JOHN GREEN       P          US
# 1807  P60005907      FLEMING-HODGE, LORI LYNN       P          US
# 1808  P60005535          EMRIT, RONALD SATISH       P          US
# 1809  P60005931   BUTTOCKS, SYDNEYS VOLUPTOUS       P          US
# 1810  S6CA00568                MOLNAR, ROBERT       S          CA
# 1811  S6MD03524               HOLMES, GREGORY       S          MD
# 1812  H6AS00031  HUNKIN-FINAU, VAITINASA SALU       H          AS
# 1813  H6AK00235               LINDBECK, STEVE       H          AK
#
#       can_off_dis can_par_aff can_inc_cha_ope_sea  \
# 0            12.0         REP           INCUMBENT
# 1             2.0         DEM          CHALLENGER
# 2             4.0         REP                OPEN
# 3             0.0         REP           INCUMBENT
# 4            13.0         DEM           INCUMBENT
# 5             4.0         DEM           INCUMBENT
# 6             2.0         DEM           INCUMBENT
# 7             8.0         DEM           INCUMBENT
# 8             2.0         REP           INCUMBENT
# 9             4.0         DEM           INCUMBENT
# 10            5.0         REP           INCUMBENT
# 11           11.0         REP           INCUMBENT
# 12            1.0         DEM           INCUMBENT
# 13            1.0         REP                OPEN
# 14           12.0         REP           INCUMBENT
# 15           14.0         DEM           INCUMBENT
# 16            2.0         DEM           INCUMBENT
# 17            5.0         DEM           INCUMBENT
# 18            3.0         REP           INCUMBENT
# 19           18.0         REP           INCUMBENT
# 20            8.0         REP           INCUMBENT
# 21            8.0         DEM           INCUMBENT
# 22           14.0         DEM           INCUMBENT
# 23           12.0         REP           INCUMBENT
# 24            1.0         REP           INCUMBENT
# 25            5.0         DEM           INCUMBENT
# 26            4.0         REP           INCUMBENT
# 27            6.0         REP           INCUMBENT
# 28            5.0         REP           INCUMBENT
# 29           19.0         REP                OPEN
# ...           ...         ...                 ...
# 1784          1.0         REP                OPEN
# 1785          1.0         REP                OPEN
# 1786         46.0         DEM                OPEN
# 1787          0.0         IND                OPEN
# 1788          0.0         IND                OPEN
# 1789          0.0         NNE                OPEN
# 1790          0.0         REP                OPEN
# 1791          0.0           W                OPEN
# 1792          0.0         NNE                OPEN
# 1793         11.0         GRE                OPEN
# 1794          1.0         REP                OPEN
# 1795          0.0         DEM                OPEN
# 1796          0.0         IND                OPEN
# 1797          0.0         REP                OPEN
# 1798          0.0         REP                OPEN
# 1799          0.0         REP                OPEN
# 1800          1.0         REP                OPEN
# 1801          0.0         IND                OPEN
# 1802          0.0         UNK                OPEN
# 1803          0.0         NNE                OPEN
# 1804          0.0         REP                OPEN
# 1805          0.0         REP                OPEN
# 1806          0.0         OTH                OPEN
# 1807          0.0         IND                OPEN
# 1808          0.0         DEM                OPEN
# 1809          0.0         IND                OPEN
# 1810          0.0         REP                OPEN
# 1811          0.0         REP                OPEN
# 1812          NaN         DEM                 NaN
# 1813          NaN         DEM                 NaN
#
#                                can_str1 can_str2            can_cit  ...  \
# 0                       2237 PICKENS RD      NaN            AUGUSTA  ...
# 1                           PO BOX 6578      NaN       PHILADELPHIA  ...
# 2               3817 VICKERS LAKE DRIVE      NaN       JACKSONVILLE  ...
# 3                          409 2ND ST W      NaN          WHITEFISH  ...
# 4                  409 13TH ST, 17TH FL      NaN            OAKLAND  ...
# 5                        P. O. BOX 1986      NaN            RALEIGH  ...
# 6                            PO BOX 327      NaN            MADISON  ...
# 7                       105 FARRAGUT RD      NaN       SOUTH BOSTON  ...
# 8                   1504 SHERMAN AVENUE      NaN         HOOD RIVER  ...
# 9                         PO BOX 590464      NaN             NEWTON  ...
# 10           N76 W14726 NORTH POINT DR.      NaN    MENOMONEE FALLS  ...
# 11                       P. O. BOX 1007      NaN            WEBSTER  ...
# 12                   138 TURNER FARM RD      NaN        NORTH HAVEN  ...
# 13                301 BROOKS STREET, SE      NaN  FORT WALTON BEACH  ...
# 14                           PO BOX 606      NaN     TARPON SPRINGS  ...
# 15                     205 HAWTHORNE CT      NaN         PITTSBURGH  ...
# 16                        P.O. BOX 4572      NaN            BOULDER  ...
# 17                          PO BOX 6072      NaN        MINNEAPOLIS  ...
# 18                      215 MAIN STREET      NaN       ST ELIZABETH  ...
# 19                 11607 N GLENSHIRE DR      NaN             DUNLAP  ...
# 20                     P. O. BOX 411486      NaN          MELBOURNE  ...
# 21            1751 POTOMAC GREENS DRIVE      NaN         ALEXANDRIA  ...
# 22                     20580 WAYLAND ST      NaN         SOUTHFIELD  ...
# 23                  6830 MAHOGANY DRIVE      NaN             GALENA  ...
# 24            234 JEFFERSON HEIGHTS AVE      NaN          JEFFERSON  ...
# 25                     2015 WALLACE RD.      NaN            ATLANTA  ...
# 26                        PO BOX 338018      NaN            GREELEY  ...
# 27                  1919 OXMOOR RD #235      NaN         BIRMINGHAM  ...
# 28                 1528 MUIRFIELD DRIVE      NaN      BOWLING GREEN  ...
# 29                     610 S. BOULEVARD      NaN              TAMPA  ...
# ...                                 ...      ...                ...  ...
# 1784             100 A WEST MAIN STREET      NaN             FULTON  ...
# 1785                      P.O. BOX 7154      NaN             TUPELO  ...
# 1786                   81 RAINBOW RIDGE      NaN             POMONA  ...
# 1787                  1119 WHITE STREET      NaN           KEY WEST  ...
# 1788                 7300 SEA GRAPE AVE      NaN        PORT RICHEY  ...
# 1789                 316 N AVENUE A #82      NaN        CASA GRANDE  ...
# 1790                   325 S BLUE HERON      NaN              NAMPA  ...
# 1791                      18116 9TH ST.      NaN        BLOOMINGTON  ...
# 1792                    6086 HAPPY LANE      NaN              NAMPA  ...
# 1793                    269 12TH STREET      NaN           BROOKLYN  ...
# 1794                1604 BRIAR RIDGE RD      NaN             TUPELO  ...
# 1795   555 TWIN DOLPHIN DRIVE SUITE 130      NaN       REDWOOD CITY  ...
# 1796                   1502 15TH AVE SW      NaN            OLYMPIA  ...
# 1797                     235 W CHESTNUT      NaN              OLNEY  ...
# 1798  9900 CORPORATE CAMPUS DR STE 3000      NaN         LOUISVILLE  ...
# 1799         163-49 130TH AVENUE APT GA      NaN            JAMAICA  ...
# 1800            136 NORTH BROOKS STREET      NaN           PONTOTOC  ...
# 1801                         PO BOX 497      NaN         KENSINGTON  ...
# 1802                       PO BOX 38272      NaN            HOUSTON  ...
# 1803                         PO BOX 842      NaN         CHARLESTON  ...
# 1804                                NaN      NaN           AVENTURA  ...
# 1805                         PO BOX 704      NaN         AMAGANSETT  ...
# 1806                           PMB 1704      NaN               AZLE  ...
# 1807                     228 HICKS LANE      NaN        VIOLET HILL  ...
# 1808               4529 TOWNWALL STREET      NaN          LAS VEGAS  ...
# 1809                143 HIGHLAND AVENUE      NaN            BUFFALO  ...
# 1810                      PO BOX 321231      NaN          LOS GATOS  ...
# 1811                 13601 MACDERNUT CT      NaN     UPPER MARLBORO  ...
# 1812               PO BOX 252 VAILOAUTA      NaN          PAGO PAGO  ...
# 1813                       PO BOX 90025      NaN          ANCHORAGE  ...
#
#      cas_on_han_beg_of_per  cas_on_han_clo_of_per     net_con net_ope_exp  \
# 0                 60109.57              175613.35  1074949.50   907156.21
# 1                      NaN              105687.23  1406719.06  1298831.83
# 2                      NaN               35645.09   650855.38   656210.29
# 3                 83815.78              399122.61  4938943.74  5055942.15
# 4                 83690.60              181338.23  1197676.61   949488.98
# 5                216409.21              274287.84   725854.52   430826.04
# 6                187549.87              412220.80   970385.04   445438.15
# 7                406586.74             1010654.62  1092218.56   459790.68
# 8                997259.73             1264468.82  3004650.64  1911215.54
# 9               1400008.58             2858165.71  2784362.26  1537844.39
# 10               393925.71              489657.75   365203.15   265824.16
# 11               162472.14               76985.57   830657.86   785298.58
# 12               215458.53              546889.99   571307.98   238294.57
# 13                     NaN               45404.66   951163.89   993759.23
# 14               429105.83              306900.57  1306012.36  1260554.41
# 15               210531.58              291751.36   777713.70   454476.55
# 16                10603.18               91824.88  1281823.94  1102838.77
# 17               162747.78              365620.60  2294848.39  1622329.10
# 18               965976.43             1941810.36  1795890.99   550469.87
# 19                     NaN              460882.83  2424378.83  1941921.99
# 20               342230.68              588576.15   837793.04   516550.17
# 21                86253.61              814750.02  1982462.14   742454.92
# 22                89131.21              228308.15   766433.08   498853.15
# 23              2501982.76             5201935.66  4258847.29  1318584.81
# 24               482793.91              455004.90   863953.07  2449513.59
# 25               184419.65              236216.43   980363.33   655566.55
# 26               140466.09              401585.47   808161.67   550056.91
# 27               189712.50              781799.96  1175074.52   451946.24
# 28               492878.98              879548.37   998358.48   384494.66
# 29                     NaN              281520.97  4550062.50  4718541.53
# ...                    ...                    ...         ...         ...
# 1784                   NaN                    NaN   101100.00   178100.00
# 1785                   NaN                    NaN   212756.00   459834.76
# 1786                   NaN                    NaN     3111.94     3111.94
# 1787                   NaN                    NaN         NaN         NaN
# 1788                   NaN                 950.00     4000.00     2200.00
# 1789                 11.00                   1.00         NaN         NaN
# 1790                   NaN                    NaN         NaN         NaN
# 1791                   NaN                    NaN         NaN         NaN
# 1792                754.92                1918.42    10487.10     9655.02
# 1793                   NaN                 257.89    14241.00    13356.89
# 1794                   NaN                    NaN   102538.35   247121.35
# 1795                   NaN                    NaN    15250.00    15221.00
# 1796                 50.00                  50.00         NaN         NaN
# 1797                   NaN                    NaN         NaN         NaN
# 1798                705.00                    NaN         NaN         NaN
# 1799                   NaN                    NaN         NaN         NaN
# 1800                   NaN                    NaN   140858.00   528638.39
# 1801                   NaN                 619.00         NaN         NaN
# 1802                   NaN                    NaN         NaN         NaN
# 1803               4413.35                2977.33    25025.00    22065.98
# 1804                   NaN                    NaN         NaN         NaN
# 1805                   NaN                    NaN         NaN         NaN
# 1806                   NaN                    NaN         NaN         NaN
# 1807               1000.00                 125.00         NaN         NaN
# 1808                   NaN                    NaN         NaN         NaN
# 1809               5000.00                5000.00         NaN         NaN
# 1810               1000.00                    NaN     1000.00     1000.00
# 1811                   NaN                    NaN         NaN         NaN
# 1812               1058.44                4561.00    41670.00    38167.44
# 1813                   NaN               64115.92   876316.81   792150.89
#
#      deb_owe_by_com deb_owe_to_com cov_sta_dat cov_end_dat winner     votes
# 0     $1,125,000.00            NaN    1/1/2015  10/19/2016      Y  158708.0
# 1               NaN            NaN   11/2/2015  10/19/2016      Y  310770.0
# 2        $60,000.00            NaN    4/1/2016  10/19/2016      Y  286018.0
# 3               NaN            NaN    1/1/2015  10/19/2016      Y  280476.0
# 4         $4,401.75            NaN    1/1/2015  10/19/2016      Y  277390.0
# 5               NaN            NaN    1/1/2015  10/19/2016      Y  275501.0
# 6               NaN            NaN    1/1/2015  10/19/2016      Y  273520.0
# 7               NaN        1750.00    1/1/2015  10/19/2016      Y  267944.0
# 8               NaN            NaN    1/1/2015  10/19/2016      Y  267179.0
# 9               NaN            NaN    1/1/2015  10/19/2016      Y  261356.0
# 10              NaN            NaN    1/1/2015  10/19/2016      Y  260705.0
# 11              NaN            NaN    1/1/2015  10/19/2016      Y  257881.0
# 12       $20,000.00            NaN    1/1/2015  10/19/2016      Y  255428.0
# 13      $120,000.00            NaN    1/1/2016  10/19/2016      Y  254280.0
# 14              NaN            NaN    1/1/2015  10/19/2016      Y  253347.0
# 15              NaN            NaN    1/1/2015  10/19/2016      Y  252709.0
# 16              NaN            NaN    1/1/2015  10/19/2016      Y  251988.0
# 17              NaN            NaN    1/1/2015  10/19/2016      Y  249957.0
# 18    $1,050,000.00            NaN    1/1/2015  10/19/2016      Y  248880.0
# 19              NaN            NaN    1/1/2015  10/19/2016      Y  248701.0
# 20              NaN            NaN    1/1/2015  10/19/2016      Y  246257.0
# 21              NaN            NaN    1/1/2015  10/19/2016      Y  245775.0
# 22              NaN            NaN    1/1/2015  10/19/2016      Y  244220.0
# 23              NaN            NaN    1/1/2015  10/19/2016      Y  243970.0
# 24              NaN            NaN    1/1/2015  10/19/2016      Y  243575.0
# 25              NaN            NaN    1/1/2015  10/19/2016      Y  241773.0
# 26              NaN            NaN    1/1/2015  10/19/2016      Y  241424.0
# 27              NaN            NaN    1/1/2015  10/19/2016      Y  240897.0
# 28              NaN            NaN    1/1/2015  10/19/2016      Y  240036.0
# 29      $450,000.00            NaN    4/1/2016  10/19/2016      Y  238975.0
# ...             ...            ...         ...         ...    ...       ...
# 1784            NaN            NaN    1/1/2015   9/30/2015    NaN       NaN
# 1785            NaN            NaN    1/1/2015   9/30/2015    NaN       NaN
# 1786            NaN            NaN   6/10/2015   9/30/2015    NaN       NaN
# 1787            NaN            NaN    7/1/2015   9/30/2015    NaN       NaN
# 1788            NaN            NaN   4/28/2015   9/30/2015    NaN       NaN
# 1789      $4,325.00            NaN    1/1/2015   8/30/2015    NaN       NaN
# 1790            NaN            NaN    4/8/2015   7/15/2015    NaN       NaN
# 1791            NaN            NaN   6/25/2015   7/15/2015    NaN       NaN
# 1792            NaN            NaN    1/1/2015    7/8/2015    NaN       NaN
# 1793            NaN            NaN    1/1/2015    7/7/2015    NaN       NaN
# 1794            NaN            NaN    1/1/2015    7/1/2015    NaN       NaN
# 1795      $1,098.00            NaN    1/1/2015   6/30/2015    NaN       NaN
# 1796            NaN            NaN    4/1/2015   6/30/2015    NaN       NaN
# 1797            NaN            NaN    6/9/2015   6/30/2015    NaN       NaN
# 1798            NaN            NaN    1/1/2015   6/30/2015    NaN       NaN
# 1799            NaN            NaN    1/1/2015   6/30/2015    NaN       NaN
# 1800            NaN            NaN    1/1/2015   6/30/2015    NaN       NaN
# 1801            NaN            NaN    4/1/2015   6/30/2015    NaN       NaN
# 1802          $1.00            NaN    1/1/2015   6/30/2015    NaN       NaN
# 1803            NaN            NaN    1/1/2015   6/30/2015    NaN       NaN
# 1804            NaN            NaN    5/1/2015   6/15/2015    NaN       NaN
# 1805            NaN            NaN    5/1/2015   6/15/2015    NaN       NaN
# 1806            NaN            NaN    7/1/2012   5/31/2015    NaN       NaN
# 1807            NaN            NaN    3/1/2015   4/30/2015    NaN       NaN
# 1808            NaN            NaN    1/1/2015    4/4/2015    NaN       NaN
# 1809            NaN            NaN    3/3/2015   3/31/2015    NaN       NaN
# 1810            NaN            NaN    1/1/2015   3/31/2015    NaN       NaN
# 1811            NaN            NaN   8/29/2017    2/1/2015    NaN       NaN
# 1812            NaN            NaN    7/1/2016  10/19/2016    NaN       NaN
# 1813     $13,979.83            NaN    4/1/2016  10/19/2016    NaN       NaN
#
# [1814 rows x 51 columns]
