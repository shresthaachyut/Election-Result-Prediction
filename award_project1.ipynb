# %%
import pandas as pd

# %%
candidate_data = pd.read_csv("./Resources/CandidateSummaryAction.csv") 
candidate_data.head()
# Out:
#       can_id           can_nam can_off can_off_sta  can_off_dis can_par_aff  \
# 0  H2GA12121  ALLEN, RICHARD W       H          GA         12.0         REP
# 1  H6PA02171     EVANS, DWIGHT       H          PA          2.0         DEM
# 2  H6FL04105  RUTHERFORD, JOHN       H          FL          4.0         REP
# 3  H4MT01041     ZINKE, RYAN K       H          MT          0.0         REP
# 4  H8CA09060      LEE, BARBARA       H          CA         13.0         DEM
#
#   can_inc_cha_ope_sea                 can_str1 can_str2       can_cit  ...  \
# 0           INCUMBENT          2237 PICKENS RD      NaN       AUGUSTA  ...
# 1          CHALLENGER              PO BOX 6578      NaN  PHILADELPHIA  ...
# 2                OPEN  3817 VICKERS LAKE DRIVE      NaN  JACKSONVILLE  ...
# 3           INCUMBENT             409 2ND ST W      NaN     WHITEFISH  ...
# 4           INCUMBENT     409 13TH ST, 17TH FL      NaN       OAKLAND  ...
#
# ...

# %%
data_details = pd.read_csv("./Resources/DataDetails.csv") 
data_details.head()
# Out:
#            Tag                                 Field Name  Data Type  \
# 0      lin_ima  Link to list of reports for the committee        URI
# 1       can_id                               Candidate Id  Character
# 2      can_nam                             Candidate Name  Character
# 3      can_off                           Candidate Office       Text
# 4  can_off_sta                     Candidate Office State  Character
#
#                                          Description              Range  \
# 0  List of all disclosure filings for this committee                NaN
# 1                                                NaN       9 characters
# 2                                  Name of candidate  Max 90 characters
# 3                                office abbreviation        1 character
# 4                      Postal abbreviation for state       2 characters
#
#                                          Explanation
# 0  Link to list of filings made directly by the c...
# ...

# %%
columns = {}
detail_it = data_details.iterrows()
print(next(detail_it))

for row in detail_it:
    oldName = row[1][0]
    newName = row[1][1]
    columns[oldName] = newName

print(columns)
# Out:
# (0, Tag                                                      lin_ima
# Field Name             Link to list of reports for the committee
# Data Type                                                    URI
# Description    List of all disclosure filings for this committee
# Range                                                        NaN
# Explanation    Link to list of filings made directly by the c...
# Name: 0, dtype: object)
# ...

# %%
col = {}
col["Tag"] = "Field Name"

print(col)

df.rename(index=str, columns=col)
# Out:
# {'Tag': 'Field Name'}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-2d0554617c73> in <module>
#       4 print(col)
#       5
# ----> 6 df.rename(index=str, columns=col)
#
# NameError: name 'df' is not defined

# %%
candidate_data.rename(columns=columns)
candidate_data.to_csv('Resources/renamedCols.csv')

# %%
candidate_data['winner'] = candidate_data['winner'].fillna(value="N")
candidate_data
# Out:
#          can_id                       can_nam can_off can_off_sta  \
# 0     H2GA12121              ALLEN, RICHARD W       H          GA
# 1     H6PA02171                 EVANS, DWIGHT       H          PA
# 2     H6FL04105              RUTHERFORD, JOHN       H          FL
# 3     H4MT01041                 ZINKE, RYAN K       H          MT
# 4     H8CA09060                  LEE, BARBARA       H          CA
# 5     H6NC04037               PRICE, DAVID E.       H          NC
# 6     H2WI02124                   POCAN, MARK       H          WI
# 7     H2MA09072                LYNCH, STEPHEN       H          MA
# 8     H6OR02116         WALDEN, GREGORY P MR.       H          OR
# 9     H2MA04073         KENNEDY, JOSEPH P III       H          MA
# 10    H8WI09050   SENSENBRENNER, F. JAMES JR.       H          WI
# 11    H0FL08208               WEBSTER, DANIEL       H          FL
# 12    H8ME01120            PINGREE, CHELLIE M       H          ME
# ...

# %%
my_list = [4, 8, 1, 4, 8, 3, 9, 11, 200]
numerator = sum(my_list)
denominator = len(my_list)
average_of_list = numerator/denominator
average_of_list
# Out:
# 27.555555555555557

# %%
def average(my_list):
    numerator = sum(my_list)
    denominator = len(my_list)
    return numerator/denominator

# %%
print(average([4, 8, 1, 4, 8, 3, 9, 11, 200]))
print(average([4, 30, 8, 3, 9, 11, 200]))
# Out:
# 27.555555555555557
# 37.857142857142854
